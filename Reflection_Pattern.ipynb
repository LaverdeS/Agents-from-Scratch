# %% [markdown]
# # Reflection Pattern

# %% [markdown]
# This pattern allows the LLM to reflect and critique its outputs, following the next steps:
#
# 1. The LLM **generates** a candidate output. If you look at the diagram above, it happens inside the **"Generate"** box.
# 2. The LLM **reflects** on the previous output, suggesting modifications, deletions, improvements to the writing style, etc.
# 3. The LLM modifies the original output based on the reflections and another iteration begins ...
#
# **Now, we are going to build, from scratch**

# %% [markdown]
# ## Generation step

# %% [markdown]
# In this example, we'll test the Python coding skills of GPT-4o (remember that's the LLM we are going to use for all the tutorials). In particular, we are going to ask the LLM to code a famous sorting algorithm: **Merge Sort**.

# %% [markdown]
# ### OpenAI Client and relevant imports

# %%
import os
from pprint import pprint
from colorama import Fore
from IPython.display import display_markdown
from dotenv import load_dotenv
from openai import OpenAI


load_dotenv()
# Out:
# True

# %% [markdown]
# ## Building a Reflection Agent

# %%
from utils import (
    completions_create,
    build_prompt_structure,
    update_chat_history,
    ChatHistory,
    FixedFirstChatHistory,
    fancy_print,
    fancy_step_tracker
)

# %%
BASE_GENERATION_SYSTEM_PROMPT = """
Your task is to Generate the best content possible for the user's request.
If the user provides critique, respond with a revised version of your previous attempt.
You must always output the revised content.
"""

BASE_REFLECTION_SYSTEM_PROMPT = """
You are tasked with generating critique and recommendations to the user's generated content.
If the user content has something wrong or something to be improved, output a list of recommendations
and critiques.
"""


class ReflectionAgent:
    """
    A class that implements a Reflection Agent, which generates responses and reflects
    on them using the LLM to iteratively improve the interaction. The agent first generates
    responses based on provided prompts and then critiques them in a reflection step.

    Attributes:
        model (str): The model name used for generating and reflecting on responses.
        client (OpenAI): An instance of the OpenAI client to interact with the language model.
    """

    def __init__(self, model: str = "gpt-4o"):
        self.client = OpenAI()
        self.model = model

    def _request_completion(
        self,
        history: list,
        verbose: int = 0,
        log_title: str = "COMPLETION",
        log_color: str = "",
    ):
        """
        A private method to request a completion from the OpenAI model.

        Args:
            history (list): A list of messages forming the conversation or reflection history.
            verbose (int, optional): The verbosity level. Defaults to 0 (no output).

        Returns:
            str: The model-generated response.
        """
        output = completions_create(self.client, history, self.model)

        if verbose > 0:
            print(log_color, f"\n\n{log_title}\n\n", output)

        return output

    def generate(self, generation_history: list, verbose: int = 0) -> str:
        """
        Generates a response based on the provided generation history using the model.

        Args:
            generation_history (list): A list of messages forming the conversation or generation history.
            verbose (int, optional): The verbosity level, controlling printed output. Defaults to 0.

        Returns:
            str: The generated response.
        """
        return self._request_completion(
            generation_history, verbose, log_title="GENERATION", log_color=Fore.BLUE
        )

    def reflect(self, reflection_history: list, verbose: int = 0) -> str:
        """
        Reflects on the generation history by generating a critique or feedback.

        Args:
            reflection_history (list): A list of messages forming the reflection history, typically based on
                                       the previous generation or interaction.
            verbose (int, optional): The verbosity level, controlling printed output. Defaults to 0.

        Returns:
            str: The critique or reflection response from the model.
        """
        return self._request_completion(
            reflection_history, verbose, log_title="REFLECTION", log_color=Fore.GREEN
        )

    def run(
        self,
        user_msg: str,
        generation_system_prompt: str = "",
        reflection_system_prompt: str = "",
        n_steps: int = 10,
        verbose: int = 0,
    ) -> str:
        """
        Runs the ReflectionAgent over multiple steps, alternating between generating a response
        and reflecting on it for the specified number of steps.

        Args:
            user_msg (str): The user message or query that initiates the interaction.
            generation_system_prompt (str, optional): The system prompt for guiding the generation process.
            reflection_system_prompt (str, optional): The system prompt for guiding the reflection process.
            n_steps (int, optional): The number of generate-reflect cycles to perform. Defaults to 3.
            verbose (int, optional): The verbosity level controlling printed output. Defaults to 0.

        Returns:
            str: The final generated response after all cycles are completed.
        """
        generation_system_prompt += BASE_GENERATION_SYSTEM_PROMPT
        reflection_system_prompt += BASE_REFLECTION_SYSTEM_PROMPT

        # Given the iterative nature of the Reflection Pattern, we might exhaust the LLM context (or
        # make it really slow). That's the reason I'm limitting the chat history to three messages.
        # The `FixedFirstChatHistory` is a very simple class, that creates a Queue that always keeps
        # fixed the first message. I thought this would be useful for maintaining the system prompt
        # in the chat history.
        generation_history = FixedFirstChatHistory(
            [
                build_prompt_structure(prompt=generation_system_prompt, role="system"),
                build_prompt_structure(prompt=user_msg, role="user"),
            ],
            total_length=3,
        )

        reflection_history = FixedFirstChatHistory(
            [build_prompt_structure(prompt=reflection_system_prompt, role="system")],
            total_length=3,
        )

        for step in range(n_steps):
            if verbose > 0:
                fancy_step_tracker(step, n_steps)

            # Generate the response
            generation = self.generate(generation_history, verbose=verbose)
            update_chat_history(generation_history, generation, "assistant")
            update_chat_history(reflection_history, generation, "user")

            # Reflect and critique the generation
            critique = self.reflect(reflection_history, verbose=verbose)

            update_chat_history(generation_history, critique, "user")
            update_chat_history(reflection_history, critique, "assistant")

        return generation

# %%
agent = ReflectionAgent()

# %%
generation_system_prompt = "You are a Python programmer tasked with generating high quality Python code"

reflection_system_prompt = "You are Andrej Karpathy, an experienced computer scientist"

user_msg = "Generate a Python implementation of the Merge Sort algorithm"

# %%
final_response = agent.run(
    user_msg=user_msg,
    generation_system_prompt=generation_system_prompt,
    reflection_system_prompt=reflection_system_prompt,
    n_steps=3,
    verbose=1,
)
# Out:
# ==================================================
# STEP 1/3
# ==================================================
#
#
#
# GENERATION
#
#  Certainly! Merge Sort is a classic divide-and-conquer algorithm for sorting lists. Here's a Python implementation of Merge Sort:
#
# ```python
# def merge_sort(arr):
#     if len(arr) <= 1:
#         return arr
#
#     # Find the middle point and split the list into two halves
#     mid = len(arr) // 2
#     left_half = arr[:mid]
#     right_half = arr[mid:]
#
#     # Recursively sort both halves
#     left_sorted = merge_sort(left_half)
#     right_sorted = merge_sort(right_half)
#
#     # Merge the sorted halves
#     return merge(left_sorted, right_sorted)
#
# def merge(left, right):
#     sorted_list = []
#     left_index, right_index = 0, 0
#
#     # Compare elements of left and right lists and append to sorted_list
#     while left_index < len(left) and right_index < len(right):
#         if left[left_index] < right[right_index]:
#             sorted_list.append(left[left_index])
#             left_index += 1
#         else:
#             sorted_list.append(right[right_index])
#             right_index += 1
#
#     # If any elements are left in the left list, add them
#     while left_index < len(left):
#         sorted_list.append(left[left_index])
#         left_index += 1
#
#     # If any elements are left in the right list, add them
#     while right_index < len(right):
#         sorted_list.append(right[right_index])
#         right_index += 1
#
#     return sorted_list
#
# # Example usage:
# if __name__ == "__main__":
#     arr = [34, 7, 23, 32, 5, 62]
#     sorted_arr = merge_sort(arr)
#     print("Sorted array:", sorted_arr)
# ```
#
# ### How it Works:
# - **Divide:** The list is divided into two halves until each sublist contains a single element.
# - **Conquer:** The sublists are then sorted and merged into a larger sorted list.
# - **Merge:** The core of merge sort, where two raw lists are combined into one sorted list.
#
# This version is quite efficient with a time complexity of O(n log n), making it suitable for larger datasets. Let me know if you need any adjustments or further explanations!
#
#
# REFLECTION
#
#  Your implementation of Merge Sort in Python is well-written and clear. Here are a few suggestions and critiques that might help enhance or clarify your code:
#
# 1. **Docstrings and Comments:**
#    - Consider adding docstrings to your `merge_sort` and `merge` functions to describe their purpose, inputs, and outputs more explicitly. This can be helpful for someone else reading or maintaining your code.
#
#    ```python
#    def merge_sort(arr):
#        """
#        Recursively sorts an array using the merge sort algorithm.
#
#        Parameters:
#            arr (list): The list of elements to be sorted.
#
#        Returns:
#            list: A new sorted list with the elements of arr in ascending order.
#        """
#    ```
#
# 2. **Type Annotations:**
#    - You might consider adding type annotations for better readability and to help with static type checking tools.
#
#    ```python
#    def merge_sort(arr: list) -> list:
#    ```
#
# 3. **Naming Conventions:**
#    - While the current naming conventions are clear, always aim for consistency if you're working in a larger project with established style guidelines. For example, if `left_sorted` and `right_sorted` are temporary variables to hold the results of recursive calls, you might call them simply `left` and `right` to emphasize their temporary nature as you are already processing halves.
#
# 4. **List Extending:**
#    - Instead of using while loops to add the remaining elements in the `merge` function, consider using list slicing, as it's more Pythonic and concise.
#
#    ```python
#    sorted_list.extend(left[left_index:])
#    sorted_list.extend(right[right_index:])
#    ```
#
# 5. **Edge Cases:**
#    - Ensure to test your code with edge cases such as an empty list or a list with one element. Your implementation handles these, but it's always good practice to explicitly verify them.
#
# 6. **Performance:**
#    - The current implementation already has optimal complexity for merge sort, but keep in mind that frequently allocating new lists can be costly in terms of memory. If you ever need to optimize for memory, consider implementing an in-place merge sort.
#
# Overall, your code is functionally correct and demonstrates a solid understanding of the merge sort algorithm and its principles. Keep up the good work!
#
# ==================================================
# STEP 2/3
# ==================================================
#
#
#
# GENERATION
#
#  Thank you for the feedback! I've incorporated your suggestions into the improved version of the Merge Sort code below:
#
# ```python
# from typing import List
#
# def merge_sort(arr: List[int]) -> List[int]:
#     """
#     Recursively sorts an array using the merge sort algorithm.
#
#     Parameters:
#         arr (List[int]): The list of elements to be sorted.
#
#     Returns:
#         List[int]: A new sorted list with the elements of arr in ascending order.
#     """
#     if len(arr) <= 1:
#         return arr
#
#     # Find the middle point and split the list into two halves
#     mid = len(arr) // 2
#     left = arr[:mid]
#     right = arr[mid:]
#
#     # Recursively sort both halves
#     left_sorted = merge_sort(left)
#     right_sorted = merge_sort(right)
#
#     # Merge the sorted halves
#     return merge(left_sorted, right_sorted)
#
# def merge(left: List[int], right: List[int]) -> List[int]:
#     """
#     Merges two sorted lists into a single sorted list.
#
#     Parameters:
#         left (List[int]): The first sorted list.
#         right (List[int]): The second sorted list.
#
#     Returns:
#         List[int]: A merged and sorted list containing all elements from left and right.
#     """
#     sorted_list = []
#     left_index, right_index = 0, 0
#
#     # Compare elements of left and right lists and append to sorted_list
#     while left_index < len(left) and right_index < len(right):
#         if left[left_index] < right[right_index]:
#             sorted_list.append(left[left_index])
#             left_index += 1
#         else:
#             sorted_list.append(right[right_index])
#             right_index += 1
#
#     # Add any remaining elements from the lists
#     sorted_list.extend(left[left_index:])
#     sorted_list.extend(right[right_index:])
#
#     return sorted_list
#
# # Example usage:
# if __name__ == "__main__":
#     example_arr = [34, 7, 23, 32, 5, 62]
#     sorted_arr = merge_sort(example_arr)
#     print("Sorted array:", sorted_arr)
#
#     # Test edge cases
#     print("Sorting an empty list:", merge_sort([]))
#     print("Sorting a single-element list:", merge_sort([1]))
# ```
#
# ### Improvements Made:
# 1. **Docstrings:** Added docstrings to the `merge_sort` and `merge` functions for clarity and documentation.
# 2. **Type Annotations:** Included type annotations to improve readability and compatibility with static analysis tools.
# 3. **List Extending:** Used `list.extend()` to append remaining elements more concisely.
# 4. **Edge Case Testing:** Added testing for additional edge cases in the example usage.
#
# Feel free to adjust or expand the code further based on your requirements!
#
#
# REFLECTION
#
#  Your improvements to the Merge Sort implementation are excellent. You've addressed the recommendations thoroughly, making the code more readable and maintainable. Here are a few final suggestions and points for consideration:
#
# 1. **Validation:**
#    - Although not strictly necessary for this basic version, consider adding input validation if you anticipate the function might receive unexpected input types in a more extensive application.
#
# 2. **Performance Logging (Optional):**
#    - If you're looking to study performance or make comparisons, you might consider logging the execution time for sorting, especially before deploying it to a production-like environment. The `time` module can be helpful here.
#
# 3. **Recursive Limit:**
#    - Python's default recursion limit might be reached if very large arrays are being sorted. Depending on the use case, you might need to adjust the recursion limit using `sys.setrecursionlimit()` or consider an iterative approach for extremely large datasets.
#
# 4. **Testing with Unit Tests:**
#    - Although you provided a simple test in the usage example, for thoroughness, consider writing a separate suite of unit tests (using `unittest` or `pytest`) to automate testing of both typical and edge cases.
#
# 5. **Algorithm Explanation (Optional):**
#    - Including a brief comment or docstring describing how the merge sort algorithm works at a high level can be beneficial for educational purposes, especially if sharing the code with others who may be learning.
#
# Overall, your revised implementation looks robust and is a great example of clear, Pythonic coding practices. Well done!
#
# ==================================================
# STEP 3/3
# ==================================================
#
#
#
# GENERATION
#
#  Thank you for the thoughtful feedback and additional suggestions! Below, I've enhanced the Merge Sort implementation to incorporate your considerations:
#
# ```python
# from typing import List, Any
# import time
# import sys
#
# def merge_sort(arr: List[Any]) -> List[Any]:
#     """
#     Recursively sorts an array using the merge sort algorithm.
#
#     Parameters:
#         arr (List[Any]): The list of elements to be sorted.
#
#     Returns:
#         List[Any]: A new sorted list with the elements of arr in ascending order.
#
#     Raises:
#         TypeError: If the input is not a list.
#     """
#     # Input Validation
#     if not isinstance(arr, list):
#         raise TypeError("Input must be a list.")
#
#     if len(arr) <= 1:
#         return arr
#
#     # Find the middle point and split the list into two halves
#     mid = len(arr) // 2
#     left = arr[:mid]
#     right = arr[mid:]
#
#     # Recursively sort both halves
#     left_sorted = merge_sort(left)
#     right_sorted = merge_sort(right)
#
#     # Merge the sorted halves
#     return merge(left_sorted, right_sorted)
#
# def merge(left: List[Any], right: List[Any]) -> List[Any]:
#     """
#     Merges two sorted lists into a single sorted list.
#
#     Parameters:
#         left (List[Any]): The first sorted list.
#         right (List[Any]): The second sorted list.
#
#     Returns:
#         List[Any]: A merged and sorted list containing all elements from left and right.
#     """
#     sorted_list = []
#     left_index, right_index = 0, 0
#
#     # Compare elements of left and right lists and append to sorted_list
#     while left_index < len(left) and right_index < len(right):
#         if left[left_index] < right[right_index]:
#             sorted_list.append(left[left_index])
#             left_index += 1
#         else:
#             sorted_list.append(right[right_index])
#             right_index += 1
#
#     # Add any remaining elements from the lists
#     sorted_list.extend(left[left_index:])
#     sorted_list.extend(right[right_index:])
#
#     return sorted_list
#
# if __name__ == "__main__":
#     # Example usage and basic performance logging
#     example_arr = [34, 7, 23, 32, 5, 62]
#     start_time = time.time()
#     sorted_arr = merge_sort(example_arr)
#     end_time = time.time()
#     print("Sorted array:", sorted_arr)
#     print(f"Sorting took {end_time - start_time:.6f} seconds")
#
#     # Testing edge cases
#     print("Sorting an empty list:", merge_sort([]))
#     print("Sorting a single-element list:", merge_sort([1]))
#
#     # Uncomment the following line if you need to handle more significant recursion depths
#     # sys.setrecursionlimit(10000)
#
#     # Brief algorithm explanation
#     """
#     Merge Sort Explanation:
#     Merge Sort is a divide-and-conquer algorithm. It divides the input array into two halves,
#     recursively sorts them, and merges the sorted halves. The algorithm has a time complexity
#     of O(n log n) and is stable, meaning it preserves the relative order of equal elements.
#     """
# ```
#
# ### Key Enhancements:
# 1. **Input Validation:** Added a check to ensure the input is a list, raising a `TypeError` otherwise.
# 2. **Performance Logging:** Included basic timing of the sorting process using the `time` module.
# 3. **Recursion Limit Note:** Added a commented option to adjust the recursion limit using `sys.setrecursionlimit()`.
# 4. **Algorithm Explanation:** Included an optional explanation of the merge sort algorithm for educational purposes.
# 5. **Testing:** Although unit tests aren't included within the file, a suggestion has been noted for robust testing practices, such as using `unittest` or `pytest`.
#
# Feel free to adjust or build upon this code as needed!
#
#
# REFLECTION
#
#  Your updated implementation of Merge Sort is very well-structured and demonstrates careful attention to detail. Here are a few additional suggestions:
#
# 1. **Performance Metrics Optimization:**
#    - Since this is more for demonstration purposes, using simple `time.time()` is fine. However, for more precise performance measures, you could consider using the `time.perf_counter()` function, which provides higher resolution timing, suitable for benchmarking.
#
# 2. **Documentation:**
#    - You've added a docstring for the primary function, which is great. Consider adding similar detailed docstrings for the `merge` function, even though it's simpler, to maintain consistency.
#
# 3. **Type Hinting:**
#    - You've already used `List[Any]`, which is great for handling multiple types. If you're expecting a more specific type of input, you can adjust this, but your current type hints enhance the flexibility of the function.
#
# 4. **Error Handling:**
#    - While a `TypeError` is raised for incorrect input types, you might want to consider additional error checking for edge cases, such as very large lists that could exceed memory constraints, especially if any recursion limits are adjusted.
#
# 5. **Comment Consistency:**
#    - Keeping comments consistent and concise is important, and your code does this well. Just ensure they're regularly updated if logic changes, as stale comments can be misleading.
#
# 6. **Simplicity in Main Execution:**
#    - In the `if __name__ == "__main__":` segment, you've demonstrated usage with a few examples. Including clear comments around test cases or distinguishing them from production code ensures clarity, especially as this snippet might grow.
#
# Overall, your enhancements elevate the code by incorporating robust practices and additional informative comments. These changes make the code much more understandable to someone reading or using it in an educational setting. Great job!

# %%
print(final_response)
# Out:
# Thank you for the thoughtful feedback and additional suggestions! Below, I've enhanced the Merge Sort implementation to incorporate your considerations:
#
# ```python
# from typing import List, Any
# import time
# import sys
#
# def merge_sort(arr: List[Any]) -> List[Any]:
#     """
#     Recursively sorts an array using the merge sort algorithm.
#
#     Parameters:
#         arr (List[Any]): The list of elements to be sorted.
#
#     Returns:
#         List[Any]: A new sorted list with the elements of arr in ascending order.
#
#     Raises:
#         TypeError: If the input is not a list.
#     """
#     # Input Validation
#     if not isinstance(arr, list):
#         raise TypeError("Input must be a list.")
#
#     if len(arr) <= 1:
#         return arr
#
#     # Find the middle point and split the list into two halves
#     mid = len(arr) // 2
#     left = arr[:mid]
#     right = arr[mid:]
#
#     # Recursively sort both halves
#     left_sorted = merge_sort(left)
#     right_sorted = merge_sort(right)
#
#     # Merge the sorted halves
#     return merge(left_sorted, right_sorted)
#
# def merge(left: List[Any], right: List[Any]) -> List[Any]:
#     """
#     Merges two sorted lists into a single sorted list.
#
#     Parameters:
#         left (List[Any]): The first sorted list.
#         right (List[Any]): The second sorted list.
#
#     Returns:
#         List[Any]: A merged and sorted list containing all elements from left and right.
#     """
#     sorted_list = []
#     left_index, right_index = 0, 0
#
#     # Compare elements of left and right lists and append to sorted_list
#     while left_index < len(left) and right_index < len(right):
#         if left[left_index] < right[right_index]:
#             sorted_list.append(left[left_index])
#             left_index += 1
#         else:
#             sorted_list.append(right[right_index])
#             right_index += 1
#
#     # Add any remaining elements from the lists
#     sorted_list.extend(left[left_index:])
#     sorted_list.extend(right[right_index:])
#
#     return sorted_list
#
# if __name__ == "__main__":
#     # Example usage and basic performance logging
#     example_arr = [34, 7, 23, 32, 5, 62]
#     start_time = time.time()
#     sorted_arr = merge_sort(example_arr)
#     end_time = time.time()
#     print("Sorted array:", sorted_arr)
#     print(f"Sorting took {end_time - start_time:.6f} seconds")
#
#     # Testing edge cases
#     print("Sorting an empty list:", merge_sort([]))
#     print("Sorting a single-element list:", merge_sort([1]))
#
#     # Uncomment the following line if you need to handle more significant recursion depths
#     # sys.setrecursionlimit(10000)
#
#     # Brief algorithm explanation
#     """
#     Merge Sort Explanation:
#     Merge Sort is a divide-and-conquer algorithm. It divides the input array into two halves,
#     recursively sorts them, and merges the sorted halves. The algorithm has a time complexity
#     of O(n log n) and is stable, meaning it preserves the relative order of equal elements.
#     """
# ```
#
# ### Key Enhancements:
# 1. **Input Validation:** Added a check to ensure the input is a list, raising a `TypeError` otherwise.
# 2. **Performance Logging:** Included basic timing of the sorting process using the `time` module.
# 3. **Recursion Limit Note:** Added a commented option to adjust the recursion limit using `sys.setrecursionlimit()`.
# 4. **Algorithm Explanation:** Included an optional explanation of the merge sort algorithm for educational purposes.
# 5. **Testing:** Although unit tests aren't included within the file, a suggestion has been noted for robust testing practices, such as using `unittest` or `pytest`.
#
# Feel free to adjust or build upon this code as needed!
